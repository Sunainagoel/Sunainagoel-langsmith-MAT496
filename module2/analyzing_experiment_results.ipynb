# %% [markdown]
# ## When we open the experiments summary view we can see a list of all the experiments we ran and a graph summarising the findings of the experiment.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### We can add filters on this experiments tab and see specific experiment data for example here we filtered according to the model name
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### This will open once we click on an experiment to enlarge it, here we can see all the parameters neatly organized in a table.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Here we selected some other filter like latecncy
#
# ![image.png](attachment:image.png)
