# %% [markdown]
# # PROMPT CANVAS

# %% [markdown]
# #### Prompt canvas interface:
#
# ![image-7.png](attachment:image-7.png)
#
# #### I asked it to give my chatbot the persona of a pirate
#
# ![image-2.png](attachment:image-2.png)
#
# #### Using diff we can see the difference between our last prompt and the current fabricated prompt
#
# ![image.png](attachment:image.png)
#
# __We can also type in extra details like in this example I have typed how this pirate fought a huge kraken__
#
# #### Thiss is what we would see in the playground when we click on "use this version" and then ask our LLM a question
#
# ![image-3.png](attachment:image-3.png)
#
# #### We can also ask the llm edit only a specific part of our code like this:
#
# ![image-4.png](attachment:image-4.png)
#
# #### We can aso add our own custom actions using this button in the prompt canvas: Here I have made an action called fix grammar which fixes the grammar in our code.
#
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)
